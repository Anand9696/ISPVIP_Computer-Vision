# %% [markdown]
# # Computer Vision Intern at Infopillar Solutions for December 2021 Batch
#
# # Author : Anand Bhausaheb Kharabe
#
# # Task 1 :  Edge & Contour Detection

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img = cv2.imread('bat.jpg')

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# # Canny edge detection
#
# The Canny edge detection algorithm is composed of 5 steps:
#
# Noise reduction, Gradient calculation, Non-maximum suppression,Double threshold, Edge Tracking by Hysteresis

# %%
edges = cv2.Canny(img, 50, 100, 3, L2gradient=True)
plt.figure()

plt.figure(figsize=(8.5,8.5))
plt.subplot(1,2,1),plt.imshow(img),plt.title("GRAY")
plt.imsave('bat-canny.jpg', edges, cmap='gray', format='jpg')
plt.imshow(edges, cmap='gray')
plt.subplot(1,2,2),plt.imshow(img),plt.title("BrBG")
plt.imsave('bat-canny.jpg', edges, cmap='BrBG', format='jpg')
plt.imshow(edges, cmap='BrBG')
plt.show()
plt.show()

# %% [markdown]
# # Contour Detection

# %%
img = cv2.imread('bat.jpg')
plt.imshow(img)
#Converting it to RGB and then grayscale:

# convert to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# create a binary threshold image
_, binary = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)
plt.imshow(binary, cmap="gray")
plt.show()

# %%
# Find the contours from the thresholded image
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img = cv2.drawContours(img, contours, -1, (0, 255, 0), 2)
plt.imshow(img)
plt.show()
