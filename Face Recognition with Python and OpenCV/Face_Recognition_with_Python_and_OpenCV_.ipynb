# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.1 MB 1.3 MB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=a27c8308ceced4812eca8782191fa12579ea61d1c4362bad56b2be3f3e8ad84e
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %% [markdown]
# # Computer Vision Intern at Infopillar Solutions for December 2021 Batch
# # Author : Anand Bhausaheb Kharabe
# # Task 1 : Face Recognition with Python and OpenCV

# %%
import cv2
from google.colab.patches import cv2_imshow

import face_recognition


imgmain = face_recognition. load_image_file ('sachin.jpeg' )

imgmain = cv2.cvtColor(imgmain, cv2.COLOR_BGR2RGB) 
imgTest = face_recognition. load_image_file ('sachin.jpeg') 
imgTest = cv2.cvtColor(imgTest, cv2.COLOR_BGR2RGB)

faceLoc = face_recognition. face_locations (imgmain) [0]

encodeElon = face_recognition.face_encodings (imgmain) [0]

cv2.rectangle(imgmain, (faceLoc[3], faceLoc[0]), (faceLoc[1], faceLoc[2]), (255, 0, 255), 2) 

faceLocTest = face_recognition.face_locations(imgTest) [0]

encodeTest = face_recognition. face_encodings(imgTest)[0]

cv2.rectangle(imgTest, (faceLocTest[3], faceLocTest[0]), (faceLocTest[1], faceLocTest[2]), (255, 0, 255), 2) 

results = face_recognition. compare_faces([encodeElon], encodeTest) 
faceDis = face_recognition.face_distance([encodeElon], encodeTest) 
print(results, faceDis)

cv2.putText(imgTest, f'{results} {round(faceDis[0], 2)}', (50, 50), cv2. FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2) 

cv2_imshow(imgmain)

cv2_imshow( imgTest)

cv2.waitKey (0)
# Out:
# [True] [0.]
# <PIL.Image.Image image mode=RGB size=260x235 at 0x7FE6A2B8AA10>
# <PIL.Image.Image image mode=RGB size=260x235 at 0x7FE6A2B48C50>
# -1
